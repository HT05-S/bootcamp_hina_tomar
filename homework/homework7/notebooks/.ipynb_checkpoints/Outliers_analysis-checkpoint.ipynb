# %% [markdown]
# ## GENERATING DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

np.random.seed(7)
x = np.linspace(0, 10, 60)
y = 1.5 * x + 0.5 + np.random.normal(0, 1.5, size=x.size)
# Inject a few extreme points
y[8] += 40
y[53] -= 42
y[47] += 32
df = pd.DataFrame({'x': x, 'y': y})
df.head()
# Out:
#           x         y
# 0  0.000000  3.035789
# 1  0.169492  0.055331
# 2  0.338983  1.057705
# 3  0.508475  1.873986
# 4  0.677966  0.333565

# %%
plt.figure()
plt.scatter(df['x'], df['y'])
plt.title('Scatter with Potential Outliers')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## DETECTING OUTLIERS USING IQR

# %%
def detect_outliers_iqr(series: pd.Series, k: float = 1.5) -> pd.Series:
    """Return boolean mask where True indicates an outlier by IQR rule.
    Parameters
    ----------
    series : pd.Series
        Numeric series to evaluate.
    k : float
        Multiplier for IQR to set fences (default 1.5).
    """
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1
    lower = q1 - k * iqr
    upper = q3 + k * iqr
    return (series < lower) | (series > upper)

df['outlier_iqr'] = detect_outliers_iqr(df['y'])
df['outlier_iqr'].value_counts()
# Out:
# outlier_iqr
# False    57
# True      3
# Name: count, dtype: int64

# %% [markdown]
# ## BOXPLOT DEPICTING POTENTIAL OUTLIERS

# %%
plt.figure()
plt.boxplot(df['y'], vert=True)
plt.title('Boxplot of y (with potential outliers)')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## DETECTING OUTLIERS USING ZSCORE

# %%
def detect_outliers_zscore(series: pd.Series, threshold: float = 1.5) -> pd.Series:
    """Return boolean mask where True indicates |z| > threshold."""
    mu = series.mean()
    sigma = series.std(ddof=0)
    z = (series - mu) / (sigma if sigma != 0 else 1.0)
    return z.abs() > threshold

df['outlier_z'] = detect_outliers_zscore(df['y'], threshold=3.0)
pd.crosstab(df['outlier_iqr'], df['outlier_z'])
# Out:
# outlier_z    False  True
# outlier_iqr
# False           57      0
# True             0      3

# %%
def winsorize_series(series: pd.Series, lower: float = 0.05, upper: float = 1.5) -> pd.Series:
    """Return a winsorized copy of the series, clipping to given quantiles."""
    lo = series.quantile(lower)
    hi = series.quantile(upper)
    return series.clip(lower=lo, upper=hi)

df_filtered = df.loc[~df['outlier_iqr'], ['x', 'y']].reset_index(drop=True)
df_w = df.copy()
df_w['y_w'] = winsorize_series(df_w['y'], lower=0.05, upper=0.95)

# %%
plt.figure()
plt.hist(df['y'], bins=20, alpha=0.7)
plt.title('Histogram of y (original)')
plt.xlabel('y')
plt.ylabel('count')
plt.show()

plt.figure()
plt.hist(df_w['y_w'], bins=20, alpha=0.7)
plt.title('Histogram of y (winsorized)')
plt.xlabel('y_w')
plt.ylabel('count')
plt.show()

# %%
def fit_and_metrics(X: np.ndarray, y: np.ndarray) -> dict:
    model = LinearRegression()
    model.fit(X, y)
    y_hat = model.predict(X)
    return {
        'slope': float(model.coef_[0]),
        'intercept': float(model.intercept_),
        'r2': float(r2_score(y, y_hat)),
        'mae': float(mean_absolute_error(y, y_hat))
    }

# All data
m_all = fit_and_metrics(df[['x']].to_numpy(), df['y'].to_numpy())
# Filtered (no IQR outliers)
m_flt = fit_and_metrics(df_filtered[['x']].to_numpy(), df_filtered['y'].to_numpy())
# Winsorized
m_win = fit_and_metrics(df[['x']].to_numpy(), df_w['y_w'].to_numpy())

sens_table = pd.DataFrame([m_all, m_flt, m_win], index=['all', 'filtered_iqr', 'winsorized'])
sens_table
# Out:
#                  slope  intercept        r2       mae
# all           1.099658   2.940636  0.116290  3.599000
# filtered_iqr  1.509846   0.294478  0.889602  1.201656
# winsorized    1.311633   1.349978  0.641460  1.734557

# %%
plt.figure()
plt.scatter(df['x'], df['y'], label='all')
x_line = np.linspace(df['x'].min(), df['x'].max(), 100).reshape(-1,1)
def line(slope, intercept):
    return slope * x_line[:,0] + intercept
plt.plot(x_line, line(m_all['slope'], m_all['intercept']), label='fit: all')
plt.plot(x_line, line(m_flt['slope'], m_flt['intercept']), label='fit: filtered')
plt.plot(x_line, line(m_win['slope'], m_win['intercept']), label='fit: winsorized')
plt.legend()
plt.title('Regression Fits Across Treatments')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
sens_table.to_csv('sens_stage07_demo.csv', index=True)
sens_table
# Out:
#                  slope  intercept        r2       mae
# all           1.099658   2.940636  0.116290  3.599000
# filtered_iqr  1.509846   0.294478  0.889602  1.201656
# winsorized    1.311633   1.349978  0.641460  1.734557

# %% [markdown]
# ## ASSUMPTIONS & RISKS INVOLVED
#
# 1) I worked on outlier detection using "IQR" as well as "ZSCORE" method. Outer fencing for both of them is with 1.5. Model was able to detect 3 outliers this is exactly the number which I want to identify.
# 2) Removing outliers often assumes that the “true” distribution is smooth (like Gaussian) and extreme points are “errors.”
# 3) Sometimes outliers are bad data.Other times they’re real rare events.
# 4) In Finance, Outliers often correspond to crisis scenarios, liquidity shocks, fat-tail events. Ignoring them is ignoring what risk managers, regulators, and portfolio managers care about.
