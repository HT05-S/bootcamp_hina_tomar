# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler

csv_path = 'data/raw_data.csv'
os.makedirs('data', exist_ok=True)

if not os.path.exists(csv_path):
    df_demo = pd.DataFrame({
    "CustomerID": [1, 2, 3, 4, 5, 6, None, 8, 9, 10],
    "Name": ["Hina", "Shivam", "Tanya", "Shubham", "Eve", "Samarth", "Priyanshi", "Eric", "Rehan", "Jigyasa"],
    "Age": [25, 30, np.nan, 40, 22, 35, 28, None, 42, 29],
    "Gender": ["F", "M", "M", "M", "F", "M", "F", "F", None, "M"],
    "Country": ["USA", "Canada", "USA", "UK", "Canada", "USA", "UK", "UK", "USA", None],
    "SignupDate": pd.date_range(start="2023-01-01", periods=10, freq="15D"),
    "PurchaseAmount": [250.5, 300.0, np.nan, 450.0, 150.0, 500.0, 275.0, 325.0, None, 400.0],
    "Membership": ["Gold", "Silver", "Gold", "None", "Gold", "Silver", "Gold", "None", "Silver", "Gold"]
})
    df_demo.to_csv(csv_path, index=False)
    print(f"Demo CSV created at {csv_path}")
else:
    print(f"CSV already exists at {csv_path}")
# Out:
# CSV already exists at data/raw_data.csv

# %%
# Loaading Raw Data
df = pd.read_csv('data/raw_data.csv')
df.head()
# Out:
#    CustomerID     Name   Age Gender Country  SignupDate  PurchaseAmount  \
# 0         1.0     Hina  25.0      F     USA  2023-01-01           250.5
# 1         2.0   Shivam  30.0      M  Canada  2023-01-16           300.0
# 2         3.0    Tanya   NaN      M     USA  2023-01-31             NaN
# 3         4.0  Shubham  40.0      M      UK  2023-02-15           450.0
# 4         5.0      Eve  22.0      F  Canada  2023-03-02           150.0
#
#   Membership
# 0       Gold
# 1     Silver
# 2       Gold
# 3        NaN
# 4       Gold

# %% [markdown]
# INSPECTING MISSED VALUES-

# %%
# Basic info and missing counts
df.info()
df.isna().sum()

# Heatmap for missing data
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# missingno visualization
msno.matrix(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      9 non-null      float64
#  1   Name            10 non-null     object
#  2   Age             8 non-null      float64
#  3   Gender          9 non-null      object
#  4   Country         9 non-null      object
#  5   SignupDate      10 non-null     object
#  6   PurchaseAmount  8 non-null      float64
#  7   Membership      8 non-null      object
# dtypes: float64(3), object(5)
# memory usage: 772.0+ bytes
# <Axes: >
